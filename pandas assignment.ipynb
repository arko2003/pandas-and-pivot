# %%
import pandas as pd

#a. Reading the autos file into pandas DataFrame
pd.read_csv("C:/Users/SOLO's WORK-IN/Downloads/autos.csv")
# Out:
#      symboling         make fuel_type aspiration  num_of_doors   body_style  \
# 0            3  alfa-romero       gas        std             2  convertible
# 1            3  alfa-romero       gas        std             2  convertible
# 2            1  alfa-romero       gas        std             2    hatchback
# 3            2         audi       gas        std             4        sedan
# 4            2         audi       gas        std             4        sedan
# ..         ...          ...       ...        ...           ...          ...
# 188         -1        volvo       gas        std             4        sedan
# 189         -1        volvo       gas      turbo             4        sedan
# 190         -1        volvo       gas        std             4        sedan
# 191         -1        volvo    diesel      turbo             4        sedan
# 192         -1        volvo       gas      turbo             4        sedan
#
# ...

# %%
#b.printing out the first 8 entries
df.head(8)
# Out:
#    symboling         make fuel_type aspiration  num_of_doors   body_style  \
# 0          3  alfa-romero       gas        std             2  convertible
# 1          3  alfa-romero       gas        std             2  convertible
# 2          1  alfa-romero       gas        std             2    hatchback
# 3          2         audi       gas        std             4        sedan
# 4          2         audi       gas        std             4        sedan
# 5          2         audi       gas        std             2        sedan
# 6          1         audi       gas        std             4        sedan
# 7          1         audi       gas        std             4        wagon
#
#   drive_wheels engine_location  wheel_base  length  ...  engine_size  \
# 0          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        88.6   168.8  ...          130
# 2          rwd           front        94.5   171.2  ...          152
# ...

# %%
# c.Groupiing the DataFrame by pricesand finding the minimum value
min_df = df.groupby('price').min()
print(min_df)
# Out:
#        symboling           make fuel_type aspiration  num_of_doors  \
# price
# 5118           2         subaru       gas        std             2
# 5151           2      chevrolet       gas        std             2
# 5195           1          mazda       gas        std             2
# 5348           1         toyota       gas        std             2
# 5389           2     mitsubishi       gas        std             2
# ...          ...            ...       ...        ...           ...
# 36880          0            bmw       gas        std             4
# 37028          3        porsche       gas        std             2
# 40960          0  mercedes-benz       gas        std             4
# 41315          0            bmw       gas        std             2
# 45400          1  mercedes-benz       gas        std             2
#
#         body_style drive_wheels engine_location  wheel_base  length  ...  \
# price                                                                ...
# ...

# %%
df.describe()
# Out:
#         symboling  num_of_doors  wheel_base      length       width  \
# count  193.000000    193.000000  193.000000  193.000000  193.000000
# mean     0.797927      3.160622   98.923834  174.326425   65.893782
# std      1.235582      0.989583    6.152409   12.478593    2.137795
# min     -2.000000      2.000000   86.600000  141.100000   60.300000
# 25%      0.000000      2.000000   94.500000  166.300000   64.100000
# 50%      1.000000      4.000000   97.000000  173.200000   65.400000
# 75%      2.000000      4.000000  102.400000  184.600000   66.900000
# max      3.000000      4.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  num_of_cylinders  engine_size        bore  \
# count  193.000000   193.000000        193.000000   193.000000  193.000000
# mean    53.869948  2561.507772          4.419689   128.124352    3.330622
# std      2.394770   526.700026          1.023182    41.590452    0.272385
# ...

# %%
df= Data
pivot= pd.df.pivot_table()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SOLO'S~1\AppData\Local\Temp/ipykernel_3088/2232159997.py in <module>
# ----> 1 df= Data
#       2 pivot= pd.df.pivot_table()
#
# NameError: name 'Data' is not defined

# %%
 pd.read_csv("C:/Users/SOLO's WORK-IN/Downloads/autos.csv")
std_df = df.groupby('price').std()
min_std = std_df['price'].min()
print("The smallest standard deviation of the prices is:", min_std)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# 7. creating and separating
import pandas as pd
data_1 = {'name': ['Frank','Prince','Abigail'],
        'age': [25, 30, 35],
        'gender': ['female','male','male']}
data_2 = {'name': ['Frank','Prince','Abigail'],
        'age': [15, 20, 25],
        'interest': ['music','gaming','dance']}
data_1
# Out:
# {'name': ['Frank', 'Prince', 'Abigail'],
#  'age': [25, 30, 35],
#  'gender': ['female', 'male', 'male']}

# %%
data_3=pd.merge(data_1,data_2,on='name')
data_3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SOLO'S~1\AppData\Local\Temp/ipykernel_3088/458004561.py in <module>
# ----> 1 data_3=pd.merge(data_1,data_2,on='name')
#       2 data_3
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625         validate: str | None = None,
#     626     ):
# --> 627         _left = _validate_operand(left)
# ...
